# %% [markdown]
# # In the below elements which of the following values or an expression?
# # *
# # 'hello'
# # -87.8
# # -
# #  /
# # +
# # 6
#
#
# * is an expression
# 'hello' is an value
# -87.8 is a value
# - is a expression
# / is a expression
# + is a expression
# 6 is a value
#
#
#
# # difference between string and variable?
#
# string can be written in quotes example.."kasana",'kasana'.
# variables is a thing in which we can store data just like a container.
#
# # describe three data types?
#
# list...list is used to storing multiple data items in a single variable.
# integer...can store only numericals value.
# float...can store only floating values such as 12.34,34.54,etc.
#
# # what is expression made up of ? what do all expression do?
#
# expression is made up of values,container and mathematicals opeartors(operand)
# example.. a=8+9 and expression are used to evaluate the values or represent the result on the screen.
#
# # this assignment statements,like spam=10.what is the difference between an expression and a statement?
#
# expression is made up of values, container and mathematicals oerators(operands) and the statements is just like a command that a python interpreter executes like print.
#
# # after running the code, what does the variable bacon contain?
# # bacon=22
# # bacon+1
#
# output is 23
#
#
# # what should the value of the following two terms be?
# # 'spam'+'spamspam'
#    'spamspamspam'
# # 'spam'*3
#    'spamspamspam'
#
# # why is eggs a valid variable name while 100 is invalid?
#
#   because we can not start giving variable an integer name.if we, we should begin with,a string-like alphabet name then integer.e100 or eggs100 is valid.
#
# # what three function can be used to get the integer,floating-point number,or string version of a value?
#
# str(),int(),float()
#
# # why does this expression cause an error? how can you fix it?
# # 'i have eaten'+99+'burritos'
#
# because 99 is an integer it can not be concatenate with string ,if we have to concatenate it we need to do typecasting.
